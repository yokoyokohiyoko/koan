# %% [markdown]
# # 辞書
#
# + 各問題の下にコードセルを追加し、**答え**と同じ出力するようにコードを書いてください

# %% [markdown]
# ## ｄを値で並べ直す（昇順、降順両方）
#
# ```python
# d = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
# ```
#
# **答え**:
# ```
# {0: 0, 2: 1, 1: 2, 4: 3, 3: 4}
# {3: 4, 4: 3, 1: 2, 2: 1, 0: 0}
# ```

# %% [markdown]
# ## d に　{2: 30} を追記する。
#
# ```
# d = {0:10, 1:20}
# ```
#
# **答え**:
# ```
# {0: 10, 1: 20, 2: 30}
# ```

# %% [markdown]
# ## 複数の辞書をマージする
#
# ```
# dic1={1:10, 2:20}
#
# dic2={3:30, 4:40}
#
# dic3={5:50,6:60}
# ```
#
# **答え**:
# ```python
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```

# %% [markdown]
# ## キーが入っていればTrueを返す、is_key_present関数を書く
# ```
# d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```
# **答え**:
# ```
# is_key_present(5)
# # True
#
# is_key_present(9)
# # False
# ```

# %% [markdown]
# ## d を for loop してプリント(順不同）
# ```
# d = {'x': 10, 'y': 20, 'z': 30}
# ```
# **答え**:
# ```
# y,20
# z,30
# x,10
# ```

# %% [markdown]
# ## 1から10まで数字をキーに、そのキーの二乗を値に持つ辞書を生成
#
# **答え**:
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# ```

# %% [markdown]
# ## 2つの辞書を合わせて、新しい辞書 d を作る
# ```
# d1 = {'a': 100, 'b': 200}
# d2 = {'x': 300, 'y': 200}
# ```
# **答え**:
# ```
# # d
# {'x': 300, 'y': 200, 'a': 100, 'b': 200}
# ```

# %% [markdown]
# ## 辞書から文字列を生成する
# ```
# d = {'Red': 1, 'Green': 2, 'Blue': 3}
# ```
# **答え**:
#
# ```
# Redは、1
# Greenは、2
# Blueは、3
# ```

# %% [markdown]
# ## 値を足し合わせる
# ```
# my_dict = {'data1':100,'data2':-54,'data3':247}
# ```
# **答え**:
#
# ```
# 293
# ```

# %% [markdown]
# ## 辞書が空かどうか
#
# ```
# my_dict1 = {}
# my_dict2 = {"A":1}
# ```
#
# **答え**:
#
# ```python
# True
# False
# ```

# %% [markdown]
# ## student_data から重複した値を持っているアイテムを削除。
#
# ```python
# student_data = {'id1': {'class': ['V'],
#   'name': ['Sara'],
#   'subject_integration': ['english, math, science']},
#  'id2': {'class': ['V'],
#   'name': ['David'],
#   'subject_integration': ['english, math, science']},
#  'id3': {'class': ['V'],
#   'name': ['Sara'],
#   'subject_integration': ['english, math, science']},
#  'id4': {'class': ['V'],
#   'name': ['Surya'],
#   'subject_integration': ['english, math, science']}}
#   ```
#
# **答え**:
#   ```python
#   {'id1': {'class': ['V'],
#   'name': ['Sara'],
#   'subject_integration': ['english, math, science']},
#  'id2': {'class': ['V'],
#   'name': ['David'],
#   'subject_integration': ['english, math, science']},
#  'id4': {'class': ['V'],
#   'name': ['Surya'],
#   'subject_integration': ['english, math, science']}}
#   ```

# %% [markdown]
# ## 値を掛け合わせる
# ```
# my_dict = {'data1':100,'data2':-54,'data3':247}
# ```
# **答え**:
#
# ```
# -1333800
# ```

# %% [markdown]
# ## 各キーがそれぞれ11-20、21-30、31-40のリストを値として持つx、y、zのキーの辞書を作成。その後、辞書から各キーの5番目の値を出力
#
# **答え**:
#
# ```python
# {'x': [11, 12, 13, 14, 15, 16, 17, 18, 19],
#  'y': [21, 22, 23, 24, 25, 26, 27, 28, 29],
#  'z': [31, 32, 33, 34, 35, 36, 37, 38, 39]}
# 15
# 25
# 35
# ```

# %% [markdown]
# ## x, y に共通のキーを見つける
#
# ```
# x = {'key1': 1, 'key2': 3, 'key3': 2}
# y = {'key1': 1, 'key2': 2}
# ```
#
# **答え**:
#
# ```
# key1
# ```

# %% [markdown]
# ## student_details 各人の、 科目 V と 科目 VI の平均点 Avrg を入れる。
#
# ```
# student_details= [
#   {'id' : 1, 'subject' : 'math', 'V' : 70, 'VI' : 82},
#   {'id' : 2, 'subject' : 'math', 'V' : 73, 'VI' : 74},
#   {'id' : 3, 'subject' : 'math', 'V' : 75, 'VI' : 86}
# ]
# ```
# **答え**:
#
# ```python
# ## 改行されていなくてもOKを
# [{'subject': 'math', 'id': 1, 'Avrg': 76.0},
# {'subject': 'math', 'id': 2, 'Avrg': 73.5},
# {'subject': 'math', 'id': 3, 'Avrg': 80.5}]
# ```

# %% [markdown]
# ## 2つのリストから辞書を作る
#
# ```python
# class_list = ['Class-V', 'Class-VI', 'Class-VII', 'Class-VIII']
# id_list = [1, 2, 2, 3]
# ```
# **答え**:
#
# ```python
# {'Class-VII': 2, 'Class-VI': 2, 'Class-V': 1, 'Class-VIII': 3}
# ```

# %% [markdown]
# ## リスト l の各要素をキーに、出現回数を値に持つ辞書を返す
#
# ```python
# l = list("zxcvbnbcvzcxvcnvbxcvvz")
# ```
# **答え**:
#
# ```python
# {'b': 3, 'c': 5, 'n': 2, 'v': 6, 'x': 3, 'z': 3}
# ```

# %% [markdown]
# ## リスト l の各要素をキーに、出現回数を値に持つ辞書を、出現回数の多い順に並べ替える
#
# ```python
# l = list("zxcvbnbcvzcxvcnvbxcvvz")
# ```
# **答え**:
#
# ```python
# [('v', 6), ('c', 5), ('z', 3), ('x', 3), ('b', 3), ('n', 2)]
# ```

# %% [markdown]
# ## student 辞書を使って下記の通り print する。(空白も考慮）
#
# ```python
# students = {
#     'Aex':{'class':'V','rolld_id':2},
#     'Puja':{'class':'V','roll_id':3}
#     }
# ```
# **答え**:
#
# ```
# Aex
# class : V
# rolld_id : 2
#
# Puja
# class :V
# roll_id : 3
# ```

# %% [markdown]
# ## dict_num  辞書を使って下記の通り print する。(空白も考慮）
#
# ```python
# dict_num = {"A": 10, "B": 20, "C": 30, "D": 40, "E": 50, "F": 60}
# ```
#
# **答え**:
#
# ```
# key	value	No
# A	10	1
# B	20	2
# C	30	3
# D	40	4
# E	50	5
# F	60	6
#
# ```

# %% [markdown]
# ## キー”A”があれば削除
#
# ```
# myDict1 = {'a':1,'b':2,'c':3,'d':4}
# myDict2 = {'b':2,'c':3,}
# ```
# **答え**:
#
# ```python
# {'b':2,'c':3,'d':4}
# {'b':2,'c':3,}
# ```

# %% [markdown]
# ## color_dict をキーでソートして、プリントする。
#
# ```python
# color_dict = {'red':'#FF0000',
#           'green':'#008000',
#           'black':'#000000',
#           'white':'#FFFFFF'}
# ```
# **答え**:
#
# ```
# black: #000000
# green: #008000
# red: #FF0000
# white: #FFFFFF
# ```

# %% [markdown]
# ## d の値で、最大値と最小値を出す。ただし、 max 関数と lambdaを使い、ワンライナー（一行）で書くこと。
#
# ```python
# d = {'x':500, 'y':5874, 'z': 560}
# ```
# **答え**:
#
# ```
# # 最大値
# 5874
#
# # 最小値
# 500
# ```

# %% [markdown]
# ## 値を重複なしで取得
#
# ```python
# L = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
# ```
#
# ```python
# {'S009', 'S002', 'S007', 'S005', 'S001'}
# ```

# %% [markdown]
# ## d を使って、出力結果と同じようにプリント
#
# ```python
# d ={'1':['a','b'], '2':['c','d'], '3': list("efg")}
# ```
# **答え**:
#
# ```
# ace
# acf
# acg
# ade
# adf
# adg
# bce
# bcf
# bcg
# bde
# bdf
# bdg
# ```

# %% [markdown]
# ## d で、値が大きいアイテムのキーを３つ返す。同値もあるので注意。
#
# ヒント： `from heapq import nlargest` を使うと楽
#
# ```python
# d = {'a':500, 'b':5874, 'c': 560,'d':400, 'e':5874, 'f': 20}
# ```
# **答え**:
#
# ```python
# ['b', 'e', 'c']
# ```

# %% [markdown]
# ## item_list で同じ item 値を持つ amount を足し合わせる
#
# ```python
# item_list = [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},
#              {'item': 'item2', 'amount': 400}, {'item': 'item1', 'amount': 750},
#              {'item': 'item3', 'amount': 10},]
# ```
#
# ```python
# {'item1': 1150, 'item2': 700, 'item3': 10}
# ```

# %% [markdown]
# ## str1 を文字数を数える
#
# ```python
# str1 = 'tokyoutoshinjukuku'
# ```
#
# **答え**:
#
# ```python
# {'t': 2, 'o': 3, 'k': 3, 'y': 1, 'u': 4, 's': 1, 'h': 1, 'i': 1, 'n': 1, 'j': 1}
#
# ```

# %% [markdown]
# ## numlist から、出力結果と同じ辞書を作る
#
# ```python
# numlist = [1, 2, 3, 4, 5, 6]
# ```
#
# **答え**:
#
# ```python
# {1: {2: {3: {4: {5: {6: {}}}}}}}
# ```
