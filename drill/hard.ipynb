# %% [markdown]
# # Koan Hard
#
# かなりpython に慣れてきた人向けの問題です．
# 必要であれば，サードパーティが作ったライブラリも利用して問題を解いて行きましょう．

# %%
# 問題はコメントで書きます．その下にコードを書いて下さい

# 問題例
# Hello を print してください

print("Hello")
# Out:
# Hello

# %% [markdown]
# ## 並べ替え

# %%
# scores を成績順に並べ替えてください
scores = {'Bigley': 9,
 'Brigid': 58,
 'Casandra': 48,
 'Clora': 11,
 'Coy': 50,
 'Halley': 46,
 'Helga': 54,
 'Isaura': 99,
 'Kinsel': 97,
 'Lauretta': 40,
 'Levar': 40,
 'Macken': 57,
 'Mcfarlin': 64,
 'Mcphee': 25,
 'Rodney': 84,
 'Scalf': 92,
 'Scally': 54,
 'Vandever': 53,
 'Vasiliki': 76,
 'Weight': 86}
